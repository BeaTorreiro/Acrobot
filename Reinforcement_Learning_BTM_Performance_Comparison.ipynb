# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# %store -r QL_avg_success
# %store -r double_avg_success
# %store -r Dueling_avg_success

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(1,1,1)
ax.plot(QL_avg_success, label="Q-Learning")
ax.plot(double_avg_success, label="Double Q-Learning")
ax.plot(Dueling_avg_success, label="Dueling Deep Q-Learning")
ax.set_title("Average successful steps comparison")
ax.set_xlabel("Steps")
ax.set_ylabel("Average Successful Steps")
ax.legend()
